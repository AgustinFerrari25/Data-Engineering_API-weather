# %% [markdown]
# # Connect to the api and extract the data

# %%
import requests
from dotenv import load_dotenv
import os

#cargamos las variables del archivo .env
load_dotenv()
key = os.getenv("KEY")

url = f'https://api.weatherapi.com/v1/forecast.json?key={key}&q=Buenos Aires&days=7&aqi=no&alerts=no'
response = requests.get(url)
data = response.json()

forecast_data_dict = {}

# Iterar sobre los datos de pronóstico
for forecast_day in data.get('forecast', {}).get('forecastday', []):
    hourly_data = forecast_day.get('hour', [])
    date = forecast_day.get('date')
    
    # Iterar sobre los datos de pronóstico cada 2 horas
    for i in range(0, len(hourly_data), 2):
        hour_data = hourly_data[i]
        time = hour_data.get('time')
        forecast_data_dict[time] = {
            'temperature_C': hour_data.get('temp_c'),
            'condition': hour_data.get('condition', {}).get('text'),
            'wind_speed_kph': hour_data.get('wind_kph'),
            'wind_direction': hour_data.get('wind_dir'),
            'pressure_mb': hour_data.get('pressure_mb'),
            'humidity_percentage': hour_data.get('humidity'),
            'cloud_cover_percentage': hour_data.get('cloud'),
            'chance_of_rain_percentage': hour_data.get('chance_of_rain'),
            'precipitation_mm': hour_data.get('precip_mm'),
            'uV_Index': hour_data.get('uv'),
        }

forecast_data_dict
# Out:
# {'2024-03-09 00:00': {'temperature_C': 23.5,
#   'condition': 'Patchy light rain in area with thunder',
#   'wind_speed_kph': 13.0,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 79,
#   'cloud_cover_percentage': 80,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.57,
#   'uV_Index': 1.0},
#  '2024-03-09 02:00': {'temperature_C': 20.7,
#   'condition': 'Moderate or heavy rain shower',
#   'wind_speed_kph': 18.0,
#   'wind_direction': 'S',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 95,
#   'cloud_cover_percentage': 90,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 3.32,
#   'uV_Index': 1.0},
#  '2024-03-09 04:00': {'temperature_C': 20.2,
#   'condition': 'Mist',
#   'wind_speed_kph': 10.1,
#   'wind_direction': 'SE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 71,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.05,
#   'uV_Index': 1.0},
#  '2024-03-09 06:00': {'temperature_C': 20.3,
#   'condition': 'Mist',
#   'wind_speed_kph': 9.4,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 54,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-09 08:00': {'temperature_C': 21.4,
#   'condition': 'Partly Cloudy ',
#   'wind_speed_kph': 5.4,
#   'wind_direction': 'NE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 94,
#   'cloud_cover_percentage': 50,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 7.0},
#  '2024-03-09 10:00': {'temperature_C': 24.8,
#   'condition': 'Partly Cloudy ',
#   'wind_speed_kph': 2.5,
#   'wind_direction': 'NNE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 79,
#   'cloud_cover_percentage': 53,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 7.0},
#  '2024-03-09 12:00': {'temperature_C': 28.3,
#   'condition': 'Cloudy ',
#   'wind_speed_kph': 5.4,
#   'wind_direction': 'SSW',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 62,
#   'cloud_cover_percentage': 72,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 7.0},
#  '2024-03-09 14:00': {'temperature_C': 30.0,
#   'condition': 'Partly cloudy',
#   'wind_speed_kph': 13.0,
#   'wind_direction': 'W',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 55,
#   'cloud_cover_percentage': 25,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 9.0},
#  '2024-03-09 16:00': {'temperature_C': 30.9,
#   'condition': 'Sunny',
#   'wind_speed_kph': 7.9,
#   'wind_direction': 'S',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 48,
#   'cloud_cover_percentage': 1,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 9.0},
#  '2024-03-09 18:00': {'temperature_C': 29.8,
#   'condition': 'Sunny',
#   'wind_speed_kph': 9.4,
#   'wind_direction': 'S',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 52,
#   'cloud_cover_percentage': 2,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 8.0},
#  '2024-03-09 20:00': {'temperature_C': 26.7,
#   'condition': 'Clear ',
#   'wind_speed_kph': 5.0,
#   'wind_direction': 'SSE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 63,
#   'cloud_cover_percentage': 1,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-09 22:00': {'temperature_C': 25.6,
#   'condition': 'Clear ',
#   'wind_speed_kph': 3.2,
#   'wind_direction': 'SSE',
#   'pressure_mb': 1011.0,
#   'humidity_percentage': 65,
#   'cloud_cover_percentage': 2,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 00:00': {'temperature_C': 24.3,
#   'condition': 'Clear ',
#   'wind_speed_kph': 4.7,
#   'wind_direction': 'SE',
#   'pressure_mb': 1012.0,
#   'humidity_percentage': 69,
#   'cloud_cover_percentage': 4,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 02:00': {'temperature_C': 23.1,
#   'condition': 'Clear ',
#   'wind_speed_kph': 9.0,
#   'wind_direction': 'E',
#   'pressure_mb': 1012.0,
#   'humidity_percentage': 78,
#   'cloud_cover_percentage': 4,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 04:00': {'temperature_C': 22.6,
#   'condition': 'Partly Cloudy ',
#   'wind_speed_kph': 15.8,
#   'wind_direction': 'E',
#   'pressure_mb': 1012.0,
#   'humidity_percentage': 88,
#   'cloud_cover_percentage': 26,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 06:00': {'temperature_C': 21.9,
#   'condition': 'Clear ',
#   'wind_speed_kph': 15.8,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1013.0,
#   'humidity_percentage': 85,
#   'cloud_cover_percentage': 18,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 08:00': {'temperature_C': 22.1,
#   'condition': 'Sunny',
#   'wind_speed_kph': 16.6,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1014.0,
#   'humidity_percentage': 82,
#   'cloud_cover_percentage': 13,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 7.0},
#  '2024-03-10 10:00': {'temperature_C': 24.9,
#   'condition': 'Sunny',
#   'wind_speed_kph': 17.3,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1014.0,
#   'humidity_percentage': 67,
#   'cloud_cover_percentage': 9,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 7.0},
#  '2024-03-10 12:00': {'temperature_C': 27.8,
#   'condition': 'Sunny',
#   'wind_speed_kph': 14.8,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1014.0,
#   'humidity_percentage': 60,
#   'cloud_cover_percentage': 14,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 8.0},
#  '2024-03-10 14:00': {'temperature_C': 30.5,
#   'condition': 'Sunny',
#   'wind_speed_kph': 14.4,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1012.0,
#   'humidity_percentage': 54,
#   'cloud_cover_percentage': 7,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 9.0},
#  '2024-03-10 16:00': {'temperature_C': 31.2,
#   'condition': 'Thundery outbreaks in nearby',
#   'wind_speed_kph': 14.4,
#   'wind_direction': 'E',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 53,
#   'cloud_cover_percentage': 27,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 8.0},
#  '2024-03-10 18:00': {'temperature_C': 28.9,
#   'condition': 'Sunny',
#   'wind_speed_kph': 15.1,
#   'wind_direction': 'E',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 61,
#   'cloud_cover_percentage': 22,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 8.0},
#  '2024-03-10 20:00': {'temperature_C': 25.6,
#   'condition': 'Partly Cloudy ',
#   'wind_speed_kph': 14.4,
#   'wind_direction': 'E',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 71,
#   'cloud_cover_percentage': 27,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-10 22:00': {'temperature_C': 25.8,
#   'condition': 'Partly Cloudy ',
#   'wind_speed_kph': 11.2,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 71,
#   'cloud_cover_percentage': 27,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-11 00:00': {'temperature_C': 26.2,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 13.0,
#   'wind_direction': 'NE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 69,
#   'cloud_cover_percentage': 80,
#   'chance_of_rain_percentage': 75,
#   'precipitation_mm': 0.02,
#   'uV_Index': 1.0},
#  '2024-03-11 02:00': {'temperature_C': 23.8,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 10.8,
#   'wind_direction': 'NE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 83,
#   'cloud_cover_percentage': 73,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.78,
#   'uV_Index': 1.0},
#  '2024-03-11 04:00': {'temperature_C': 22.5,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 12.2,
#   'wind_direction': 'NNE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 90,
#   'cloud_cover_percentage': 72,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.36,
#   'uV_Index': 1.0},
#  '2024-03-11 06:00': {'temperature_C': 22.0,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 11.2,
#   'wind_direction': 'NE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 93,
#   'cloud_cover_percentage': 77,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 2.05,
#   'uV_Index': 1.0},
#  '2024-03-11 08:00': {'temperature_C': 22.2,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 8.6,
#   'wind_direction': 'NE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 67,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.99,
#   'uV_Index': 6.0},
#  '2024-03-11 10:00': {'temperature_C': 22.3,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 4.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 93,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 2.26,
#   'uV_Index': 6.0},
#  '2024-03-11 12:00': {'temperature_C': 21.7,
#   'condition': 'Heavy rain',
#   'wind_speed_kph': 13.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 11.65,
#   'uV_Index': 6.0},
#  '2024-03-11 14:00': {'temperature_C': 20.3,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 25.2,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 88,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.21,
#   'uV_Index': 6.0},
#  '2024-03-11 16:00': {'temperature_C': 22.0,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 18.0,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 81,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 2.36,
#   'uV_Index': 6.0},
#  '2024-03-11 18:00': {'temperature_C': 23.1,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 13.7,
#   'wind_direction': 'NE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 59,
#   'chance_of_rain_percentage': 53,
#   'precipitation_mm': 0.02,
#   'uV_Index': 6.0},
#  '2024-03-11 20:00': {'temperature_C': 22.1,
#   'condition': 'Fog',
#   'wind_speed_kph': 8.6,
#   'wind_direction': 'NNE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 72,
#   'precipitation_mm': 0.03,
#   'uV_Index': 1.0},
#  '2024-03-11 22:00': {'temperature_C': 21.7,
#   'condition': 'Fog',
#   'wind_speed_kph': 5.8,
#   'wind_direction': 'NNE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-12 00:00': {'temperature_C': 21.5,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 5.8,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 74,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.39,
#   'uV_Index': 1.0},
#  '2024-03-12 02:00': {'temperature_C': 21.5,
#   'condition': 'Fog',
#   'wind_speed_kph': 6.8,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.12,
#   'uV_Index': 1.0},
#  '2024-03-12 04:00': {'temperature_C': 21.6,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 5.4,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.01,
#   'uV_Index': 1.0},
#  '2024-03-12 06:00': {'temperature_C': 21.8,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 9.7,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 95,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.53,
#   'uV_Index': 1.0},
#  '2024-03-12 08:00': {'temperature_C': 22.1,
#   'condition': 'Heavy rain',
#   'wind_speed_kph': 6.1,
#   'wind_direction': 'SSW',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 12.55,
#   'uV_Index': 6.0},
#  '2024-03-12 10:00': {'temperature_C': 22.1,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 10.4,
#   'wind_direction': 'E',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 86,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.85,
#   'uV_Index': 6.0},
#  '2024-03-12 12:00': {'temperature_C': 23.5,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 11.9,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 87,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 2.21,
#   'uV_Index': 6.0},
#  '2024-03-12 14:00': {'temperature_C': 24.3,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 16.2,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 98,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.48,
#   'uV_Index': 6.0},
#  '2024-03-12 16:00': {'temperature_C': 24.4,
#   'condition': 'Light rain',
#   'wind_speed_kph': 11.5,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 91,
#   'cloud_cover_percentage': 99,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.04,
#   'uV_Index': 6.0},
#  '2024-03-12 18:00': {'temperature_C': 23.0,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 13.3,
#   'wind_direction': 'E',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 90,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.1,
#   'uV_Index': 6.0},
#  '2024-03-12 20:00': {'temperature_C': 22.2,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 9.4,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 88,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.07,
#   'uV_Index': 1.0},
#  '2024-03-12 22:00': {'temperature_C': 22.3,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 9.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 94,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.29,
#   'uV_Index': 1.0},
#  '2024-03-13 00:00': {'temperature_C': 22.1,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 7.6,
#   'wind_direction': 'SE',
#   'pressure_mb': 1011.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.37,
#   'uV_Index': 1.0},
#  '2024-03-13 02:00': {'temperature_C': 21.9,
#   'condition': 'Fog',
#   'wind_speed_kph': 12.2,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-13 04:00': {'temperature_C': 21.8,
#   'condition': 'Fog',
#   'wind_speed_kph': 10.4,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 68,
#   'precipitation_mm': 0.01,
#   'uV_Index': 1.0},
#  '2024-03-13 06:00': {'temperature_C': 21.9,
#   'condition': 'Fog',
#   'wind_speed_kph': 10.8,
#   'wind_direction': 'SE',
#   'pressure_mb': 1011.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.05,
#   'uV_Index': 1.0},
#  '2024-03-13 08:00': {'temperature_C': 21.1,
#   'condition': 'Light drizzle',
#   'wind_speed_kph': 14.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1013.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.37,
#   'uV_Index': 6.0},
#  '2024-03-13 10:00': {'temperature_C': 19.6,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 15.5,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1013.0,
#   'humidity_percentage': 93,
#   'cloud_cover_percentage': 98,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.05,
#   'uV_Index': 5.0},
#  '2024-03-13 12:00': {'temperature_C': 21.6,
#   'condition': 'Overcast ',
#   'wind_speed_kph': 18.0,
#   'wind_direction': 'E',
#   'pressure_mb': 1012.0,
#   'humidity_percentage': 89,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 6.0},
#  '2024-03-13 14:00': {'temperature_C': 22.0,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 16.9,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1010.0,
#   'humidity_percentage': 89,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.13,
#   'uV_Index': 6.0},
#  '2024-03-13 16:00': {'temperature_C': 22.2,
#   'condition': 'Light rain',
#   'wind_speed_kph': 14.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 93,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.61,
#   'uV_Index': 6.0},
#  '2024-03-13 18:00': {'temperature_C': 21.6,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 10.8,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1009.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.43,
#   'uV_Index': 6.0},
#  '2024-03-13 20:00': {'temperature_C': 21.4,
#   'condition': 'Fog',
#   'wind_speed_kph': 11.5,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.1,
#   'uV_Index': 1.0},
#  '2024-03-13 22:00': {'temperature_C': 21.6,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 11.9,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.6,
#   'uV_Index': 1.0},
#  '2024-03-14 00:00': {'temperature_C': 22.0,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 10.8,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.7,
#   'uV_Index': 1.0},
#  '2024-03-14 02:00': {'temperature_C': 22.2,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 8.6,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.3,
#   'uV_Index': 1.0},
#  '2024-03-14 04:00': {'temperature_C': 22.4,
#   'condition': 'Fog',
#   'wind_speed_kph': 7.2,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.1,
#   'uV_Index': 1.0},
#  '2024-03-14 06:00': {'temperature_C': 22.4,
#   'condition': 'Fog',
#   'wind_speed_kph': 6.8,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1005.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 0,
#   'precipitation_mm': 0.0,
#   'uV_Index': 1.0},
#  '2024-03-14 08:00': {'temperature_C': 22.9,
#   'condition': 'Fog',
#   'wind_speed_kph': 6.5,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 99,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.4,
#   'uV_Index': 6.0},
#  '2024-03-14 10:00': {'temperature_C': 23.6,
#   'condition': 'Mist',
#   'wind_speed_kph': 4.7,
#   'wind_direction': 'ENE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.4,
#   'uV_Index': 6.0},
#  '2024-03-14 12:00': {'temperature_C': 24.6,
#   'condition': 'Mist',
#   'wind_speed_kph': 2.2,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 50,
#   'precipitation_mm': 0.01,
#   'uV_Index': 6.0},
#  '2024-03-14 14:00': {'temperature_C': 25.1,
#   'condition': 'Mist',
#   'wind_speed_kph': 2.5,
#   'wind_direction': 'SE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 94,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.2,
#   'uV_Index': 7.0},
#  '2024-03-14 16:00': {'temperature_C': 24.9,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 5.0,
#   'wind_direction': 'SSE',
#   'pressure_mb': 1005.0,
#   'humidity_percentage': 94,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.5,
#   'uV_Index': 6.0},
#  '2024-03-14 18:00': {'temperature_C': 24.0,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 9.0,
#   'wind_direction': 'S',
#   'pressure_mb': 1005.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.87,
#   'uV_Index': 6.0},
#  '2024-03-14 20:00': {'temperature_C': 23.6,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 10.1,
#   'wind_direction': 'SSE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.2,
#   'uV_Index': 1.0},
#  '2024-03-14 22:00': {'temperature_C': 23.2,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 11.2,
#   'wind_direction': 'SSE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.2,
#   'uV_Index': 1.0},
#  '2024-03-15 00:00': {'temperature_C': 22.8,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 11.9,
#   'wind_direction': 'SE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 98,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 1.0,
#   'uV_Index': 1.0},
#  '2024-03-15 02:00': {'temperature_C': 21.7,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 13.7,
#   'wind_direction': 'SE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.9,
#   'uV_Index': 1.0},
#  '2024-03-15 04:00': {'temperature_C': 20.6,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 14.8,
#   'wind_direction': 'SE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.5,
#   'uV_Index': 1.0},
#  '2024-03-15 06:00': {'temperature_C': 19.6,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 15.1,
#   'wind_direction': 'SE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 96,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 80,
#   'precipitation_mm': 0.03,
#   'uV_Index': 1.0},
#  '2024-03-15 08:00': {'temperature_C': 19.3,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 16.2,
#   'wind_direction': 'SE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 95,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.1,
#   'uV_Index': 5.0},
#  '2024-03-15 10:00': {'temperature_C': 19.6,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 16.2,
#   'wind_direction': 'SE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 92,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.1,
#   'uV_Index': 5.0},
#  '2024-03-15 12:00': {'temperature_C': 20.6,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 15.1,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1008.0,
#   'humidity_percentage': 89,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.09,
#   'uV_Index': 6.0},
#  '2024-03-15 14:00': {'temperature_C': 21.2,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 14.4,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1007.0,
#   'humidity_percentage': 88,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 89,
#   'precipitation_mm': 0.0,
#   'uV_Index': 6.0},
#  '2024-03-15 16:00': {'temperature_C': 21.3,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 14.0,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 89,
#   'cloud_cover_percentage': 98,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.1,
#   'uV_Index': 6.0},
#  '2024-03-15 18:00': {'temperature_C': 21.0,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 13.7,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1005.0,
#   'humidity_percentage': 90,
#   'cloud_cover_percentage': 95,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.13,
#   'uV_Index': 6.0},
#  '2024-03-15 20:00': {'temperature_C': 20.8,
#   'condition': 'Patchy rain nearby',
#   'wind_speed_kph': 9.7,
#   'wind_direction': 'ESE',
#   'pressure_mb': 1005.0,
#   'humidity_percentage': 94,
#   'cloud_cover_percentage': 98,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.5,
#   'uV_Index': 1.0},
#  '2024-03-15 22:00': {'temperature_C': 20.7,
#   'condition': 'Light rain shower',
#   'wind_speed_kph': 7.9,
#   'wind_direction': 'SE',
#   'pressure_mb': 1006.0,
#   'humidity_percentage': 97,
#   'cloud_cover_percentage': 100,
#   'chance_of_rain_percentage': 100,
#   'precipitation_mm': 0.6,
#   'uV_Index': 1.0}}

# %%
# Crear DataFrame de Pandas
import pandas as pd
from datetime import datetime

df = pd.DataFrame.from_dict(forecast_data_dict, orient='index').reset_index().rename(columns={"index": 'hour'})

creation_date = datetime.now()
df['creation_date'] = creation_date

df
# Out:
#                 hour  temperature_C                               condition  \
# 0   2024-03-09 00:00           23.5  Patchy light rain in area with thunder
# 1   2024-03-09 02:00           20.7           Moderate or heavy rain shower
# 2   2024-03-09 04:00           20.2                                    Mist
# 3   2024-03-09 06:00           20.3                                    Mist
# 4   2024-03-09 08:00           21.4                          Partly Cloudy
# ..               ...            ...                                     ...
# 79  2024-03-15 14:00           21.2                      Patchy rain nearby
# 80  2024-03-15 16:00           21.3                      Patchy rain nearby
# 81  2024-03-15 18:00           21.0                      Patchy rain nearby
# 82  2024-03-15 20:00           20.8                      Patchy rain nearby
# 83  2024-03-15 22:00           20.7                       Light rain shower
#
#     wind_speed_kph wind_direction  pressure_mb  humidity_percentage  \
# 0             13.0            ENE       1007.0                   79
# 1             18.0              S       1010.0                   95
# 2             10.1             SE       1009.0                   96
# 3              9.4            ENE       1008.0                   96
# 4              5.4             NE       1009.0                   94
# ..             ...            ...          ...                  ...
# 79            14.4            ESE       1007.0                   88
# 80            14.0            ESE       1006.0                   89
# 81            13.7            ESE       1005.0                   90
# 82             9.7            ESE       1005.0                   94
# 83             7.9             SE       1006.0                   97
#
#     cloud_cover_percentage  chance_of_rain_percentage  precipitation_mm  \
# 0                       80                        100              0.57
# 1                       90                        100              3.32
# 2                       71                        100              0.05
# 3                       54                          0              0.00
# 4                       50                          0              0.00
# ..                     ...                        ...               ...
# 79                     100                         89              0.00
# 80                      98                        100              0.10
# 81                      95                        100              0.13
# 82                      98                        100              0.50
# 83                     100                        100              0.60
#
#     uV_Index              creation_date
# 0        1.0 2024-03-09 14:17:50.089327
# 1        1.0 2024-03-09 14:17:50.089327
# 2        1.0 2024-03-09 14:17:50.089327
# 3        1.0 2024-03-09 14:17:50.089327
# 4        7.0 2024-03-09 14:17:50.089327
# ..       ...                        ...
# 79       6.0 2024-03-09 14:17:50.089327
# 80       6.0 2024-03-09 14:17:50.089327
# 81       6.0 2024-03-09 14:17:50.089327
# 82       1.0 2024-03-09 14:17:50.089327
# 83       1.0 2024-03-09 14:17:50.089327
#
# [84 rows x 12 columns]

# %% [markdown]
# # Connect and Create table in Redshift

# %%
df.dtypes
# Out:
# hour                                 object
# temperature_C                       float64
# condition                            object
# wind_speed_kph                      float64
# wind_direction                       object
# pressure_mb                         float64
# humidity_percentage                   int64
# cloud_cover_percentage                int64
# chance_of_rain_percentage             int64
# precipitation_mm                    float64
# uV_Index                            float64
# creation_date                datetime64[us]
# dtype: object

# %%
import psycopg2

def get_db_connection(host_instance, data_base, user, port, pwd):
    try:
        conn = psycopg2.connect(
            host=host_instance,
            dbname=data_base,
            user=user,
            password=pwd,
            port=port
        )
        print("successful connection to AWS Redshift")
        return conn
    except Exception as e:
        print("error connecting to AWS Redshift")
        print(e)

# %%
host_instance = os.getenv("AWS_HOST")
data_base = os.getenv("AWS_DB")
user = os.getenv("AWS_USER")
port = os.getenv("AWS_PORT")
pwd = os.getenv("AWS_PASSWORD")

# Llamamos a la funcion get_db_connection
conn = get_db_connection(host_instance, data_base, user, port, pwd)
# Out:
# successful connection to AWS Redshift

# %%
# Create Redshift table 
try:
    cur = conn.cursor()

    cur.execute("""
        CREATE TABLE IF NOT EXISTS forecastday_per_hour (
          hour VARCHAR(50),
          temperature_c FLOAT,
          condition VARCHAR(50),
          wind_speed_kph FLOAT,
          wind_direction VARCHAR(50),
          pressure_mb FLOAT,
          humidity_percentage INTEGER,
          cloud_cover_percentage INTEGER,
          chance_of_rain_percentage INTEGER,
          precipitation_mm FLOAT,
          uv_index FLOAT,
          creation_date TIMESTAMP
        )
    """)

    conn.commit()
    print("Table created successfully")
except Exception as e:
    print("Error creating table")
    print(e)
# Out:
# Table created successfully

# %%
cur=conn.cursor()
cur.execute("Truncate table forecastday_per_hour")

# %%
try:
    for index, row in df.iterrows():
        values = [str(value) if isinstance(value, pd.Timestamp) else value for value in row]
        insert_query = f"INSERT INTO forecastday_per_hour VALUES ({', '.join(['%s'] * len(values))});"
        cur.execute(insert_query, values)
    
    conn.commit()
    print("Data inserted successfully")
except Exception as e:
    print("Error inserting data")
    print(e)
# Out:
# Data inserted successfully
